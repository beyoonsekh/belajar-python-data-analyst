# %%
nilai_uts = [100, 99, 98, 70 ,84]

print(nilai_uts[0])
print(nilai_uts[4])
print(len(nilai_uts))
# Out:
# 100
# 84
# 5

# %%
nilai_uts = [100, 99, 98, 70 ,84]

print(nilai_uts[0])
print(nilai_uts[4])
print(nilai_uts[0:4])
print(nilai_uts[-2])
print(len(nilai_uts))
# Out:
# 100
# 84
# [100, 99, 98, 70]
# 70
# 5

# %%
nilai_uts = 60

if nilai_uts >= 85:
  print("A")

elif nilai_uts >= 70:
  print("B")

elif nilai_uts >= 55:
  print("C")
elif nilai_uts < 55:
  print("D")

else:
  print("E")

print(nilai_uts)
print("Program Selesai")
# Out:
# C
# 60
# Program Selesai

# %%
profil = {
    "nama": "Izzah",
    "semester": 2,
    "ipk": 3.82,
    "matkul_fav": "Pemrosesn data"
}

print(profil["nama"])
print(profil["semester"])
print(profil["ipk"])
print(profil["matkul_fav"])
# Out:
# Izzah
# 2
# 3.82
# Pemrosesn data
